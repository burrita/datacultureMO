# %% [markdown]
# ## Визуализация

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ## Библиотека Matplotlib
#  - <a href="http://http://matplotlib.org/">matplotlib</a> - основная библиотека для базовой визуализации данных
#
#
# `Scatter` рисует набор точек. Первый аргумент - координаты точек по оси X, второй аргумент - координаты по оси Y

# %%
# Создание графика из точек - scatter

plt.figure(figsize=[7, 5]) # figsize - размер графика, [ширина, высота] в дюймах

plt.scatter([1, 2, 3, 10, 15], [1, 2, 3, 5, 10]) # Первая точка (1, 1), вторая (2, 2), последняя (15, 10)

plt.show() # рисует сам график и выводит его нам в тетрадку

# %%
# Создание прямой из точек - plot

plt.figure(figsize=[7, 5]) # figsize - размер графика, [ширина, высота] в дюймах
plt.plot([1, 2, 3, 10, 15], [1, 2, 9, 5, 10]) # Первая точка (1, 1), вторая (2, 2), последняя (15, 10)
plt.show() # рисует сам график и выводит его нам в тетрадку

# %% [markdown]
# Делать график без заголовков - плохая практика. Добавить заголовок к графику можно с помощью команды `plt.title`

# %%
# Создание прямой из точек - plot

plt.figure(figsize=[7, 5]) # figsize - размер графика, [ширина, высота] в дюймах
plt.plot([1, 2, 3, 10, 15], [1, 2, 3, 5, 10]) # Первая точка (1, 1), вторая (2, 2), последняя (15, 10)
plt.title('Заголовок')
plt.show() # рисует сам график и выводит его нам в тетрадку

# %% [markdown]
# ### Красивое рисование графиков

# %% [markdown]
# #### Оформление
# - Заголовок области рисования -> plt.title()
# - Подпись оси абсцисс OX -> plt.xlabel()
# - Подпись оси ординат OY -> plt.ylabel()
# - Деления на оси абсцисс OX -> plt.xticks()
# - Деления на оси ординат OY -> plt.yticks()
# - Разбитие на красивую сеточку -> plt.grid()

# %% [markdown]
# #### Подписи
# - Легенда -> plt.legend()
#
# Перед тем как вызывать легенду, убедитесь что вы подписали графики - передали аргумент `label` в `plt.plot` или `plt.scatter`

# %%
# Создание прямой из точек - plot

plt.figure(figsize=[7, 5]) 
plt.plot([1, 2, 3, 10, 15], [1, 2, 3, 5, 10], label='Простой plot') # label - как подпишется график
plt.scatter([1.5, 2.5, 3.5, 9, 13], [1.3, 2.6, 3.1, 4.1, 7.6], label='Простой scatter') # label - как подпишется график

plt.title('Заголовок')

plt.xlabel('Подпись к X') # в скобках вводим текст, который должен появиться в качестве подписи оси х
plt.ylabel('Подпись к Y') # в скобках вводим текст, который должен появиться в качестве подписи оси y

plt.xticks([1, 2, 3, 5, 10, 11, 15, 16]) # то где на графике, на оси X будут точечки
plt.yticks([1, 2, 3, 5, 7, 8, 9, 10]) # то где на графике, на оси Y будут точечки
plt.legend()
plt.grid()

plt.show()

# %%
# Создание прямой из точек - plot

plt.figure(figsize=[7, 5]) 
plt.plot([1, 2, 3, 10, 15], [1, 2, 3, 5, 10], label='Простой plot') 
plt.scatter([1.5, 2.5, 3.5, 9, 13], [1.3, 2.6, 3.1, 4.1, 7.6], label='Простой scatter') 

plt.title('Заголовок', fontsize=15)

plt.xlabel('Подпись к X', fontsize=22)
plt.ylabel('Подпись к Y', fontsize=32)

plt.xticks([1, 2, 3, 5, 10, 11, 15, 16])
plt.yticks([1, 2, 3, 5, 7, 8, 9, 10])
plt.legend()
plt.grid()

plt.show()

# %%
plt.figure(figsize=[7, 5])   # Создание объекта Figure
plt.scatter([1.0], [1.0])   # scatter - метод для нанесения маркера в точке (1.0, 1.0)
plt.xlabel('Ось х точечки')# в скобках в кавычках вводим текст, который должен появиться в качестве подписи оси х
plt.ylabel('Ось y точечки')# в скобках в кавычках вводим текст, который должен появиться в качестве подписи оси у
plt.title('Название графика с точечкой',  fontsize = 35)
plt.xticks(np.arange(5), ('Tom', 'Dick', 'Harry', 'Sally', 'Sue'))
# итак, что у нас происходит сверху? сначала мы сказали, что у нас вся ось х будет от 0 до 4
# 5 не будет, так как в питоне последняя циферка не включительно
# значит, сказали, что вся ось от 0 до 4
# потом сказали, что хотим, чтобы она была подписана не чиселками 0,1,2,3,4,
# а именами 'Tom', 'Dick', 'Harry', 'Sally', 'Sue'
plt.yticks(np.arange(3), ('Чиселка 0', 'Чиселка 1', 'Чиселка 2'))
# с осью y сделали примерно то же самое
plt.show()

# %%
plt.figure(figsize=[7, 5]) 
plt.plot([1, 2, 3, 10, 15], [1, 2, 3, 5, 10], label='Простой plot', c='palegreen') 
plt.scatter([1.5, 2.5, 3.5, 9, 13], [1.3, 2.6, 3.1, 4.1, 7.6], label='Простой scatter', c='lightpink') 
plt.title('Заголовок', fontsize=15)

plt.xlabel('Подпись к X', fontsize=22)
plt.ylabel('Подпись к Y', fontsize=32)

plt.xticks([1, 2, 3, 5, 10, 11, 15, 16])
plt.xticks([1, 2, 3, 5, 7, 8, 9, 10])
plt.legend()
plt.grid()

plt.show()

# %% [markdown]
# Круговая диаграмма
# plt.pie()

# %%
# Задайте вектор, который будет содержать количество часов, которое Вы тратите на сон, еду, учебу/работу и развлечения (всего 4 значения)
slices = np.array([10, 2, 5, 6])


plt.figure(figsize=(10, 10))

# Labels
activities = ['Сон','Еда','Учеба/Работа','Развлечения']

#Задайте список из 4 цветов:
cols = ['red', 'salmon', 'g', 'blue']
plt.pie(slices, labels=activities, colors=cols)

plt.title(" Легкая жизнь Федора")

plt.show()

# %% [markdown]
# #### Гистограмма
# - plt.hist() - гистограмма
#
# <b> Зачем: </b> Можно показать распределение объектов по частоте их появления.
#
#
# По оси x отложены интервалы значений, а по у количество наблюдений в данном интервале.

# %%
sample = np.random.normal(size=50000)     #1000 значений из нормального распределения
plt.hist(sample)               
plt.title("Гистограмма нормального распределения")
plt.xlabel("Значение")
plt.ylabel("Частота")
# Out:
# Text(0, 0.5, 'Частота')

# %% [markdown]
# #### Boxplot (ящик с усами)

# %% [markdown]
# - plt.boxplot() - гистограмма
#
# Один из самых информативных графиков для демонстрации основного характера выборки, на иллюстрации ниже можно видеть, как интерпретировать данный график:

# %% [markdown]
# ![alt text](https://miro.medium.com/max/18000/1*2c21SkzJMf3frPXPAR_gZA.png "Боксплот")
#
# Видно, что основная часть выборки (25 - 75 персентиль) должна попадать в центральный "ящик"

# %% [markdown]
# Можно рисовать много ящиков. Для этого в plt.boxplot нужно подать двумерный массив (таблицу), для каждого столбца нарисуется свой ящик

# %%
sample = np.random.normal(size=(1000, 5))     #1000 значений из нормального распределения, 5 столбцов
plt.boxplot(sample)               
plt.title("Boxplot нормального распределения")
plt.xlabel("Значение")
plt.ylabel("Частота")
# Out:
# Text(0, 0.5, 'Частота')

# %% [markdown]
# ## Библиотека seaborn
# Это пакет-надстройка к matplotlib. Зачастую графики с помощью этой библиотеки строить проще и выглядят они красивее и эстетичнее, а ещё иногда функции этой библиотеки сами догадывается, как подписать оси.

# %%
import numpy as np
import seaborn as sns

# %% [markdown]
# Полезные функции:
# - sns.set_style() - меняет стиль области построения
# <br>
# - sns.load_dataset() - подгружает датасет из seaborn
# <br>
# - sns.set_context() - меняет оформление графика
# <br>
#
#
# Примеры графиков:
# - sns.distplot() - график распределения
# <br>
# - sns.boxplot() - боксплот
# <br>
# - sns.swarmplot() - визуализация значений признака для разных категорий
# <br>
# - sns.pairplot() - визуализация значений признаков
# <br>
# - sns.heatmap() - тепловая карта
# <br>
# - sns.barplot() - столбчатая диаграмма
# <br>
# - sns.regplot() - регрессия
# <br>
# - sns.countplot() - визуализация количества
# <br>
# - sns.jointplot() - визуализация распределение+корреляция

# %% [markdown]
# Большую часть графиков будем рассматривать на примере данных «Российский мониторинг экономического положения и здоровья населения НИУ-ВШЭ (RLMS-HSE)», проводимый Национальным исследовательским университетом "Высшая школа экономики" и ООО «Демоскоп» при участии Центра народонаселения Университета Северной Каролины в Чапел Хилле и Института социологии РАН. (Сайты обследования RLMS-HSE: http://www.cpc.unc.edu/projects/rlms и http://www.hse.ru/rlms)».
#
# Список переменных
# 1. **public** – 1 если государственное предприятие (в государственной собственности), 0 если частное;
#
# 2. **wage** – заработная плата, полученная за последние 30 дней по основному месту работы;
#
# 3. **income** – сколько всего денег за последние 30 дней получил респондент, считая все источники дохода;
#
# 4. **tenure** – опыт работы на текущем месте;
#
# 5. **educ** – уровень образования, категориальная переменная (0 для индивидов без среднего образования)
# ```
#     1 -- среднее образование
#     2 -- профессиональные курсы
#     3 -- ПТУ, техническое училище
#     4 -- техникум
#     5 -- институт, университет, академия
# ```
# 6. **urban** – 1 респондент проживает в городе, 0 в сельской местности;
# 7. **male** – пол, 1 для мужчин, 0 для женщин;
# 8. **age** – возраст;
# 9. **subordinates** – наличие подчиненных, 1 если есть, 0 в противном случае.
# 10. **experience** – число лет общего трудового стажа респондента;
# 11. **otherjob** – хотелось бы респонденту найти другую работу, 1 если да, 0 в противном случае;
# 12. **trust** – доверие мелкому и среднему частному бизнесу, 1 если респондент доверяет, 0 если не доверяет;
# 13. **internet** – приходилось ли респонденту в течение последних 12 месяцев пользоваться Интернетом, 1 если да, 0 в противном случае.

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = pd.read_csv('data_rl.csv').dropna()
print(data.shape)
data.head()
# Out:
# (4425, 14)
#       wage  income  age  educ  public  tenure  experience  subordinates  \
# 0  12000.0   12000   33   5.0     1.0    14.0        14.0             0
# 1  13000.0   13000   35   0.0     1.0    15.0        17.0             1
# 2  27000.0   32000   54   0.0     0.0     3.0        25.0             0
# 3   3000.0    3000   46   1.0     0.0     0.0        32.0             0
# 4  15000.0   15000   30   0.0     0.0     2.0        10.0             1
#
#    otherjob  internet  trust  urban  \
# 0         1         0      0      0
# 1         0         1      0      0
# 2         0         1      0      0
# 3         0         0      0      0
# 4         1         0      0      0
#
#                                               region     sex
# 0  Центральный и Центрально-Черноземный экономиче...  female
# 1  Центральный и Центрально-Черноземный экономиче...    male
# 2  Центральный и Центрально-Черноземный экономиче...  female
# 3  Центральный и Центрально-Черноземный экономиче...  female
# 4  Центральный и Центрально-Черноземный экономиче...    male

# %%
data.region.value_counts()
# Out:
# Центральный и Центрально-Черноземный экономический район    917
# Северно-Кавказский экономический район                      659
# Северный и Северо-Западный экономический район              586
# Волго-Вятский и Поволжский экономический район              448
# Уральский федеральный округ                                 381
# Западно-Сибирский экономический район                       375
# Восточный и Дальне-Восточный экономический район            339
# Уральский экономический район                               317
# Дальневосточный федеральный округ                           252
# Красноярск и Красноярский край                              150
# Приволжский федеральный округ                                 1
# Name: region, dtype: int64

# %%
region_data = data[data.region == 'Западно-Сибирский экономический район']
print(region_data.shape)
region_data.head()
# Out:
# (375, 14)
#          wage  income  age  educ  public  tenure  experience  subordinates  \
# 1342   8200.0    8200   50   5.0     1.0    15.0        24.0             0
# 1343  15000.0   15000   44   5.0     1.0     0.0        20.0             1
# 1344  25000.0   25000   45   5.0     1.0    14.0        20.0             1
# 1345   3170.0    3560   33   4.0     1.0     0.0         7.0             0
# 1346  16000.0   26000   24   5.0     0.0     0.0         6.0             0
#
#       otherjob  internet  trust  urban                                 region  \
# 1342         0         0      0      1  Западно-Сибирский экономический район
# 1343         0         1      0      1  Западно-Сибирский экономический район
# 1344         0         0      0      1  Западно-Сибирский экономический район
# 1345         1         1      0      1  Западно-Сибирский экономический район
# 1346         0         1      0      1  Западно-Сибирский экономический район
#
#          sex
# 1342  female
# 1343  female
# 1344    male
# 1345  female
# 1346  female

# %%
sns.set_style("whitegrid")
sns.distplot(region_data.age)
# Как и в matplotlib'e, можно звать функции для заголовка / подписей осей / почти чего угодно ещё
plt.title('Распределение возраста\nЗападно-Сибирский экономический район')
# Out:
# Text(0.5, 1.0, 'Распределение возраста\nЗападно-Сибирский экономический район')

# %%
sns.set_style("white")
sns.boxplot(region_data.age)
plt.show()
sns.set_style("white")
sns.boxplot(region_data.age)
plt.show()

# %%
sns.set_style("dark")
sns.swarmplot(region_data.age)
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x=region_data.sex, y=region_data.wage, palette="Pastel1")
plt.show()

# %%
plt.figure(figsize=(10, 10))
my_pal = {'male': "green", 'female': "olive"}
sns.boxplot(x=region_data.sex, y=region_data.wage, palette=my_pal)
plt.show()

# %% [markdown]
# `sns.swarmplot()` позволяет визуализировать значения признака для разных категорий.

# %%
plt.figure(figsize=(10, 10))
sns.swarmplot(x="sex", y="wage", data=region_data)
plt.show()

# %% [markdown]
# Можно менять размер изображений, используя функцию `sns.set_context()` и различные параметры: `paper`, `notebook`, `talk` и `poster`. `notebook` - дефолтный параметр. <br>

# %%
plt.figure(figsize=(10, 10))
sns.set_context("poster")  # poster увеличивает шрифт подписей
sns.swarmplot(x="sex", y="wage", data=region_data)
plt.show()

# %% [markdown]
# ### График регрессии

# %% [markdown]
# Можно построить регрессию и сразу же ее визуализировать с помощью `regplot`

# %%
sns.set()
# tips = sns.load_dataset("tips")
sns.regplot(x="age", y="wage", data=region_data)
plt.show()

# %% [markdown]
# ### Связь признаков
# Эта визуализация поможет нам посмотреть на одной картинке, как связаны между собой различные признаки. <br>
#
# На диагонали матрицы графиков расположены гистограммы распределений признака. Остальные же графики — это обычные scatter для соответствующих пар признаков.

# %%
region_data.head()
# Out:
#          wage  income  age  educ  public  tenure  experience  subordinates  \
# 1342   8200.0    8200   50   5.0     1.0    15.0        24.0             0
# 1343  15000.0   15000   44   5.0     1.0     0.0        20.0             1
# 1344  25000.0   25000   45   5.0     1.0    14.0        20.0             1
# 1345   3170.0    3560   33   4.0     1.0     0.0         7.0             0
# 1346  16000.0   26000   24   5.0     0.0     0.0         6.0             0
#
#       otherjob  internet  trust  urban                                 region  \
# 1342         0         0      0      1  Западно-Сибирский экономический район
# 1343         0         1      0      1  Западно-Сибирский экономический район
# 1344         0         0      0      1  Западно-Сибирский экономический район
# 1345         1         1      0      1  Западно-Сибирский экономический район
# 1346         0         1      0      1  Западно-Сибирский экономический район
#
#          sex
# 1342  female
# 1343  female
# 1344    male
# 1345  female
# 1346  female

# %%
columns = ['wage', 'age', 'educ', 'tenure']
sns_plot = sns.pairplot(region_data[columns])
plt.show()

# %%
sns.set()  # сброс настроек по стилям, возвращение к стилю по умолчанию

plt.figure(figsize=(16, 16))
# annot - добавляет аннотацию (цифры на карте), fmt - форматирует
sns.heatmap(region_data.corr(), annot=True, fmt=".2f")
plt.show()

# %% [markdown]
# ###  Сравнение показателей по нескольким категориям

# %% [markdown]
# - sns.barplot() - столбчатая диаграмма для визуализации распределений значений по категориям
# <br>
# - sns.countplot() - визуализация количества по категориям

# %%
sns.barplot(x="sex", y="wage", hue="educ", data=region_data)

# %%
sns.countplot(x='sex', hue='educ', data=region_data)

# %%
sns.jointplot(x='tenure', y='age', data=region_data)
